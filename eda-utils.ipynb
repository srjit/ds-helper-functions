# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import plotly.express as px
import plotly.graph_objects as go

import matplotlib
matplotlib.rcParams['font.sans-serif'] = "Gill Sans"

import matplotlib.pyplot as plt
import matplotlib.ticker as tkr



plt.style.use("ggplot")
import numpy as np
import pandas as pd
pd.options.plotting.backend = "plotly"

# %% [markdown]
# __Plot on the same canvas as subplots: Helper function for brevity__

# %%
def plot(X_,Y_, ax=None, title="", xlabel="", ylabel="", dist=None, **kwargs):

    ax = ax or plt.gca()
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

    if dist:
        ax.axvline(dist.mean(), color="black")
    return ax.scatter(X_,Y_, **kwargs)

# %% [markdown]
# __Usage Example__

# %%
# f = plt.figure(figsize=(18, 10))

# fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 4))

# plot(X,Y, ax1)
# plot(X,Y_poiss, ax1, title="Poisson Fit", xlabel="K", ylabel="Probability", alpha=0.5)
# plot(X,Y, ax2)
# plot(sorted(X),Y_neg_binomial, ax2, 
#      title="Negative Binomial Fit", 
#      xlabel="K", 
#      ylabel="Probability", 
#      dist = dist_est,
#      alpha=0.5)

# %% [markdown]
# ### Nice grid lines

# %%
Xs = list(range(1,20))
Ys = [x**2 for x in Xs]

fig, ax = plt.subplots(figsize=(10,8))
ax.plot(Xs, Ys, marker='x')
#plt.yticks(list(range(800, 1800, 300)))
ax.minorticks_on()

# Don't allow the axis to be on top of your data
ax.set_axisbelow(True)

# Turn on the minor TICKS, which are required for the minor GRID
ax.minorticks_on()

# Customize the major grid
ax.grid(which='major', linestyle='-', linewidth='0.5', color='darkred')
# Customize the minor grid
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
ax.set_ylabel("Count of customers")
ax.set_xlabel("Past 12 month PV Sum")
plt.show()

# %%
def func(x, pos):  # formatter function takes tick label and tick position
    s = '%d' % x
    groups = []
    while s and s[-1].isdigit():
        groups.append(s[-3:])
        s = s[:-3]
    return s + ','.join(reversed(groups))


y_format = tkr.FuncFormatter(func)


def plot2(X_,Y_, ax=None, title="", xlabel="", ylabel="", dist=None, **kwargs):

    ax = ax or plt.gca()
    ax.set_title(title, fontsize=20, color='darkred', fontweight="bold")
    
    ax.set_xlabel(xlabel, fontsize=13, color='darkred', fontweight="bold")
    ax.set_ylabel(ylabel, fontsize=13, color='darkred', fontweight="bold")

    ax.yaxis.set_major_formatter(y_format)
    

    
    if dist:
        ax.axvline(dist.mean(), color="black")
        
        
    X_ = [str(x) for x in X_]
    ax.set_xticklabels(X_, rotation = 90, ha="right")
    return ax.plot(X_,Y_, alpha=0.6, **kwargs)

# %%
Xs = list(range(1,20))
Ys = [x**2 for x in Xs]

plot2(Xs, Ys)

# %%
#import seaborn as sns
#sns.set_style("darkgrid")
#sns.set_theme()
#sns.set_style("darkgrid", {"axes.facecolor": ".9"})
#sns.set_context("notebook")
